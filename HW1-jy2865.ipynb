# %% [markdown]
# # COMS 4995_002 Deep Learning Assignment 1
# Due on Thursday, Feb 8, 11:59pm
#
# This assignment can be done in groups of at most 2 students. Everyone must submit on Courseworks individually.

# %% [markdown]
# Write down the UNIs of your group (if applicable)
#
# Member 1: Jiachen Yang, jy2865
#
# Member 2: Zijing Wu, zw2442

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import scipy.misc
import glob
import sys
# you shouldn't need to make any more imports

# %%
class NeuralNetwork(object):
    """
    Abstraction of neural network.
    Stores parameters, activations, cached values. 
    Provides necessary functions for training and prediction. 
    """
    def __init__(self, layer_dimensions, drop_prob=0.0, reg_lambda=0.0, optimization_methods = "SGD", beta = 1.0, beta_2 = 1.0, reg_methods="L2"):
        """
        Initializes the weights and biases for each layer
        :param layer_dimensions: (list) number of nodes in each layer
        :param drop_prob: drop probability for dropout layers. Only required in part 2 of the assignment
        :param reg_lambda: regularization parameter. Only required in part 2 of the assignment
        """
        np.random.seed(1)
        
        self.parameters = {}
        self.num_layers = len(layer_dimensions)
        self.drop_prob = drop_prob
        self.reg_lambda = reg_lambda
        self.opt_methods = optimization_methods
        self.traning = True
        self.beta = beta
        self.beta_2 = beta_2
        self.reg_methods = reg_methods
        
        # init parameters
        self.parameters['W'] = {}
        self.parameters['B'] = {}
        self.parameters['Z'] = {}
        self.parameters['A'] = {}
        self.parameters['D'] = {}
        self.parameters['m'] = {}
        self.parameters['mb'] = {}
        self.parameters['s'] = {}
        self.parameters['sb'] = {}
        for i in range(0,len(layer_dimensions)):
            self.parameters['W'][i] = np.random.randn(layer_dimensions[i], layer_dimensions[i - 1]) / np.sqrt(layer_dimensions[i - 1])
            self.parameters['B'][i] = np.zeros([layer_dimensions[i], 1])
            self.parameters['m'][i] = None
            self.parameters['mb'][i] = None
            self.parameters['D'][i] = None
            self.parameters['s'][i] = None
            self.parameters['sb'][i] = None
            # self.parameters['Z'][i] = np.zeros((layer_dimensions[i],1))
            # self.parameters['A'][i] = np.zeros((layer_dimensions[i],1))
        

    def affineForward(self, A, W, b):
        """
        Forward pass for the affine layer.
        :param A: input matrix, shape (L, S), where L is the number of hidden units in the previous layer and S is
        the number of samples
        :returns: the affine product WA + b, along with the cache required for the backward pass
        """
        Z = np.dot(W, A) + b
        
        # return affine product
        return Z
        
        

    def activationForward(self, A, activation="relu"):
        """
        Common interface to access all activation functions.
        :param A: input to the activation function
        :param prob: activation funciton to apply to A. Just "relu" for this assignment.
        :returns: activation(A)
        """ 
        if activation == "relu":
            return self.relu(A)
        elif activation == "softmax":
            return self.softmax(A)


    def relu(self, X):
        return np.maximum(0, X)
    
    def softmax(self, X):
        return np.exp(X) / np.sum(np.exp(X), axis = 0)
    
            
    def dropout(self, A, prob):
        """
        :param A: 
        :param prob: drop prob
        :returns: tuple (A, M) 
            WHERE
            A is matrix after applying dropout
            M is dropout mask, used in the backward pass
        """
        M = np.random.rand(A.shape[0],A.shape[1])
        M = (M>prob)*1.0
        M /= (1-prob)
        A *= M
        return A, M

    def forwardPropagation(self, X):
        """
        Runs an input X through the neural network to compute activations
        for all layers. Returns the output computed at the last layer along
        with the cache required for backpropagation.
        :returns: (tuple) AL, cache
            WHERE 
            AL is activation of last layer
            cache is cached values for each layer that
                     are needed in further steps
        """
        self.parameters["A"][0] = X
        
        for i in range(1, self.num_layers-1):
            Z = self.affineForward(self.parameters["A"][i-1], self.parameters["W"][i], self.parameters["B"][i])
            A = self.activationForward(Z)
            self.parameters["Z"][i] = Z
            self.parameters["A"][i] = A
            
            if self.traning and self.drop_prob > 0:
                A, M = self.dropout(A,self.drop_prob)
                self.parameters["D"][i] = M
        
        Z = self.affineForward(self.parameters["A"][self.num_layers-2], self.parameters["W"][self.num_layers-1], self.parameters["B"][self.num_layers-1])
        AL = self.activationForward(Z,"softmax")
        self.parameters["Z"][self.num_layers-1] = Z
        self.parameters["A"][self.num_layers-1] = AL
        self.parameters["D"][self.num_layers-1] = None
            
        return AL
    
    def costFunction(self, AL, y):
        """
        :param AL: Activation of last layer, shape (num_classes, S)
        :param y: labels, shape (S)
        :param alpha: regularization parameter
        :returns cost, dAL: A scalar denoting cost and the gradient of cost
        """
        # compute loss
        size = y.shape[0]
        cost = -np.sum(np.log(AL[y,range(size)]))/size
        
        if self.reg_lambda > 0:
            if self.reg_methods == "L2":
                for i in range(1,self.num_layers):
                    cost += 0.5*self.reg_lambda*np.sum(np.square(self.parameters['W'][i]))
            elif self.reg_methods == "L1":
                for i in range(1,self.num_layers):
                    cost += self.reg_lambda*np.sum(np.abs(self.parameters['W'][i]))

        # gradient of cost
        AL[y,range(size)] -= 1
        dAL = AL / size
        
        return cost, dAL

    def affineBackward(self, dA_prev, cache, cache_level):
        """
        Backward pass for the affine layer.
        :param dA_prev: gradient from the next layer.
        :param cache: cache returned in affineForward
        :returns dA: gradient on the input to this layer
                 dW: gradient on the weights
                 db: gradient on the bias
        """
        W,Z,A,D = cache
        mW,mb,s,sb = self.parameters['m'][cache_level],self.parameters['mb'][cache_level],self.parameters['s'][cache_level],self.parameters['sb'][cache_level]

        if self.drop_prob > 0 and not D is None:
            #call dropout_backward
            A = self.dropout_backward(A,D)
            
        dA = self.activationBackward(W.T@dA_prev,Z)
        dW = dA_prev@A.T
        db = np.expand_dims(np.sum(dA_prev, axis=1), axis=1)
        
        if self.opt_methods == "Momentum":
            if mW is not None:
                dW = (1-self.beta) * dW + self.beta*mW
                db = (1-self.beta) * db + self.beta*mb
            self.parameters['m'][cache_level] = dW
            self.parameters['mb'][cache_level] = db
        elif self.opt_methods == "rmsprop": 
            if s is None:
                s = np.zeros([dW.shape[0],dW.shape[1]])
                sb = np.zeros([db.shape[0],db.shape[1]])
            s = (1-self.beta) * dW * dW + self.beta * s
            dW = dW / np.sqrt(s+1e-10)
            sb = (1-self.beta) * db * db + self.beta * sb
            db = sb / np.sqrt(sb+1e-10)
            self.parameters['s'][cache_level] = s
            self.parameters['sb'][cache_level] = sb
        elif self.opt_methods == "adam":
            if mW is None:
                mW = np.zeros([dW.shape[0],dW.shape[1]])
                mb = np.zeros([db.shape[0],db.shape[1]])
            if s is None:
                s = np.zeros([dW.shape[0],dW.shape[1]])
                sb = np.zeros([db.shape[0],db.shape[1]])
                
            m = (1-self.beta) * dW + self.beta * mW
            s = (1-self.beta_2) *dW*dW + self.beta_2 * s
            dW = m / np.sqrt(s+1e-10)
            
            mb = (1-self.beta) * db + self.beta * mb
            sb = (1-self.beta_2) * db * db + self.beta_2 * sb
            db = mb / np.sqrt(sb+1e-10)
            
            self.parameters['m'][cache_level] = m
            self.parameters['mb'][cache_level] = mb
            
            self.parameters['s'][cache_level] = s
            self.parameters['sb'][cache_level] = sb
            
        
        return dA, dW, db

    def activationBackward(self, dA, cache, activation="relu"):
        """
        Interface to call backward on activation functions.
        In this case, it's just relu. 
        """
        Z = cache
        if activation == "relu":
            return dA*self.relu_derivative(Z)

        
    def relu_derivative(self, cached_x):
        
        return np.where(cached_x>0,1,0)
    
    def dropout_backward(self, dA, cache):
        return dA * cache

    def backPropagation(self, dAL, Y, cache):
        """
        Run backpropagation to compute gradients on all paramters in the model
        :param dAL: gradient on the last layer of the network. Returned by the cost function.
        :param Y: labels
        :param cache: cached values during forwardprop
        :returns gradients: dW and db for each weight/bias
        """
        gradients = {}
        L = self.num_layers
        dA_prev,dW,db = self.affineBackward(dAL,(self.parameters['W'][L-1],self.parameters['Z'][L-2],self.parameters['A'][L-2],None),L-1)
        gradients[L-1] = {}
        gradients[L-1]['dW'] = dW
        if self.reg_lambda > 0:
            if self.reg_methods == "L2":
                gradients[L-1]['dW'] += self.reg_lambda * self.parameters['W'][L-1]
            elif self.reg_methods == "L1":
                gradients[L-1]['dW'] += self.reg_lambda * np.sign(self.parameters['W'][L-1])
        gradients[L-1]['db'] = db
        
        self.parameters["D"][0] = None
        
        for i in range(L-3,-1,-1):
            dA_prev,dW,db = self.affineBackward(dA_prev,(self.parameters['W'][i+1],self.parameters['Z'][i],self.parameters['A'][i],self.parameters["D"][i]),i+1)
            gradients[i+1] = {}
            gradients[i+1]['dW'] = dW
            gradients[i+1]['db'] = db
            
            
            if self.reg_lambda > 0:
                if self.reg_methods == "L2":
                # add gradients from L2 regularization to each dW
                    gradients[i+1]['dW'] += self.reg_lambda * self.parameters['W'][i+1]
                elif self.reg_methods == "L1":
                    gradients[i+1]['dW'] += self.reg_lambda * np.sign(self.parameters['W'][i+1])
        
        return gradients


    def updateParameters(self, gradients, alpha):
        """
        :param gradients: gradients for each weight/bias
        :param alpha: step size for gradient descent 
        """
        L = self.num_layers
        
        for i in range(1,L):
#             print(gradients[i]['dW'].shape)
#             print(np.sum(np.abs(gradients[i]['dW'])))
            self.parameters['W'][i] -= alpha*gradients[i]['dW']
            self.parameters['B'][i] -= alpha*gradients[i]['db']
        
    def rotate_right(self, X):
        X_rot = []
        for i in range(len(X)):
            cur = np.reshape(X[i], (32,32,3))
            cur_rot = np.rot90(cur)
            X_rot.append(cur_rot.flatten())
        return X_rot
    
    def reflect(self, X, h, v):
        X_flip = []
        for i in range(len(X)):
            cur_flip = np.reshape(X[i], (32,32,3))
            if h:
                cur_flip = np.flipud(cur_flip)
            if v:
                cur_flip = np.fliplr(cur_flip)
            X_flip.append(cur_flip.flatten())
        return X_flip
    
    def data_aug(self, X, y, rotation=True, reflection=True):
        X_expand, y_expand = X.T, y.T
        
        if rotation:
            X_90 = self.rotate_right(X_expand)
            # X_180 = self.rotate_right(X_90)
            # X_270 = self.rotate_right(X_180)
            # X_expand = np.vstack((X_expand, X_90, X_180, X_270))
            X_expand = np.vstack((X_expand,X_90))
            y_expand = np.hstack([y_expand,y_expand])
        
        if reflection:
            X_flip_h = self.reflect(X_expand, 1, 0)
            # X_flip_v = self.reflect(X_expand, 0, 1)
            # X_flip_hv = self.reflect(X_expand, 1, 1)
            # X_expand = np.vstack((X_expand, X_flip_h, X_flip_v, X_flip_hv))
            X_expand = np.vstack((X_expand,X_flip_h))
            y_expand = np.hstack([y_expand,y_expand])
            
        return X_expand.T, y_expand.T
        

    def train(self, X, y, iters=1000, alpha=0.0001, batch_size=100, print_every=100,data_aug =None):
        """
        :param X: input samples, each column is a sample
        :param y: labels for input samples, y.shape[0] must equal X.shape[1]
        :param iters: number of training iterations
        :param alpha: step size for gradient descent
        :param batch_size: number of samples in a minibatch
        :param print_every: no. of iterations to print debug info after
        """
        if data_aug == "rotate":
            X,y = self.data_aug(X, y, rotation = True, reflection = False)
        elif data_aug == "reflect":
            X,y = self.data_aug(X, y, rotation = False, reflection = True)
        
        self.traning = True
        data_size = X.shape[1]
        train_size = int(data_size*0.9)
        random_range = np.random.permutation(data_size)
        X_train = X[:,random_range[0:train_size]]
        X_validation = X[:,random_range[train_size:data_size]]

        y_train = y[random_range[0:train_size]]
        y_validation = y[random_range[train_size:data_size]]
        
        for i in range(0, iters):
            # get minibatch
            batch_X,batch_y = self.get_batch(X_train,y_train,batch_size)
            # forward prop
            AL = self.forwardPropagation(batch_X)
            # compute loss
            cost,dAL = self.costFunction(AL,batch_y)
            # compute gradients
            self.parameters['Z'][0] = batch_X
            gradients = self.backPropagation(dAL,batch_y,None)
            # update weights and biases based on gradient
            self.updateParameters(gradients,alpha)
            if i % print_every == 0:
                # print cost, train and validation set accuracies
                y_pred = self.predict(batch_X)
                acc = float(np.sum(y_pred == batch_y))/batch_y.shape[0]
                                
                y_validation_predicted = self.predict(X_validation)
                validation_acc = float(np.sum(y_validation_predicted == y_validation))/y_validation.shape[0]
                
                print("Iteration %5d: Cost is %.6f, Accuracy is %.6f The accuracy of validation set is %f"%(i,cost,acc,validation_acc))
                
    def predict(self, X):
        """
        Make predictions for each sample
        """
        self.traning = False
        A = X
        for i in range(1, self.num_layers):
            Z = self.affineForward(A, self.parameters["W"][i], self.parameters["B"][i])
            A = self.activationForward(Z)
        
        y_pred = np.argmax(A,axis=0)

        return y_pred

    def get_batch(self, X, y, batch_size):
        """
        Return minibatch of samples and labels
        
        :param X, y: samples and corresponding labels
        :parma batch_size: minibatch size
        :returns: (tuple) X_batch, y_batch
        """
        index = np.random.randint(0,X.shape[1],size=batch_size)
        X_batch = X[:,index]
        y_batch = y[index]

        return X_batch, y_batch

# %%
# Helper functions, DO NOT modify this

def get_img_array(path):
    """
    Given path of image, returns it's numpy array
    """
    return scipy.misc.imread(path)

def get_files(folder):
    """
    Given path to folder, returns list of files in it
    """
    filenames = [file for file in glob.glob(folder+'*/*')]
    filenames.sort()
    return filenames

def get_label(filepath, label2id):
    """
    Files are assumed to be labeled as: /path/to/file/999_frog.png
    Returns label for a filepath
    """
    tokens = filepath.split('/')
    label = tokens[-1].split('_')[1][:-4]
    if label in label2id:
        return label2id[label]
    else:
        sys.exit("Invalid label: " + label)

# %%
# Functions to load data, DO NOT change these

def get_labels(folder, label2id):
    """
    Returns vector of labels extracted from filenames of all files in folder
    :param folder: path to data folder
    :param label2id: mapping of text labels to numeric ids. (Eg: automobile -> 0)
    """
    files = get_files(folder)
    y = []
    for f in files:
        y.append(get_label(f,label2id))
    return np.array(y)

def one_hot(y, num_classes=10):
    """
    Converts each label index in y to vector with one_hot encoding
    """
    y_one_hot = np.zeros((y.shape[0], num_classes))
    y_one_hot[y] = 1
    return y_one_hot.T

def get_label_mapping(label_file):
    """
    Returns mappings of label to index and index to label
    The input file has list of labels, each on a separate line.
    """
    with open(label_file, 'r') as f:
        id2label = f.readlines()
        id2label = [l.strip() for l in id2label]
    label2id = {}
    count = 0
    for label in id2label:
        label2id[label] = count
        count += 1
    return id2label, label2id

def get_images(folder):
    """
    returns numpy array of all samples in folder
    each column is a sample resized to 30x30 and flattened
    """
    files = get_files(folder)
    images = []
    count = 0
    
    for f in files:
        count += 1
        if count % 10000 == 0:
            print("Loaded {}/{}".format(count,len(files)))
        img_arr = get_img_array(f)
        img_arr = img_arr.flatten() / 255.0
        images.append(img_arr)
    X = np.column_stack(images)

    return X

def get_train_data(data_root_path):
    """
    Return X and y
    """
    train_data_path = data_root_path + 'train'
    id2label, label2id = get_label_mapping(data_root_path+'labels.txt')
    print(label2id)
    X = get_images(train_data_path)
    y = get_labels(train_data_path, label2id)
    return X, y

def save_predictions(filename, y):
    """
    Dumps y into .npy file
    """
    np.save(filename, y)

# %%
# Load the data
data_root_path = '/Users/yjc/columbia_course/deep learning/HW/cifar10-hw1/'
X_train, y_train = get_train_data(data_root_path) # this may take a few minutes
X_test = get_images(data_root_path + 'test')
print('Data loading done')
# Out:
# {'deer': 4, 'frog': 6, 'ship': 8, 'airplane': 0, 'dog': 5, 'bird': 2, 'truck': 9, 'horse': 7, 'automobile': 1, 'cat': 3}
# /Users/yjc/anaconda/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:7: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# Loaded 10000/50000
# Loaded 20000/50000
# Loaded 30000/50000
# Loaded 40000/50000
# Loaded 50000/50000
# Loaded 10000/10000
# Data loading done

# %% [markdown]
# ## Part 1
#
# #### Simple fully-connected deep neural network

# %%
layer_dimensions = [X_train.shape[0], 512, 512, 256, 256, 128, 128, 64, 32, 10]  # including the input and output layers
NN = NeuralNetwork(layer_dimensions)
NN.train(X_train, y_train, iters=15000, alpha=0.05, batch_size=200, print_every=1000)
# Out:
# Iteration     0: Cost is 2.299764, Accuracy is 0.140000 The accuracy of validation set is 0.121800
# Iteration  1000: Cost is 1.751489, Accuracy is 0.365000 The accuracy of validation set is 0.384400
# Iteration  2000: Cost is 1.530456, Accuracy is 0.495000 The accuracy of validation set is 0.374600
# Iteration  3000: Cost is 1.526228, Accuracy is 0.500000 The accuracy of validation set is 0.422200
# Iteration  4000: Cost is 1.430042, Accuracy is 0.615000 The accuracy of validation set is 0.470800
# Iteration  5000: Cost is 1.253294, Accuracy is 0.600000 The accuracy of validation set is 0.465800
# Iteration  6000: Cost is 1.251801, Accuracy is 0.680000 The accuracy of validation set is 0.502800
# Iteration  7000: Cost is 0.996773, Accuracy is 0.700000 The accuracy of validation set is 0.481600
# Iteration  8000: Cost is 0.958680, Accuracy is 0.790000 The accuracy of validation set is 0.520200
# Iteration  9000: Cost is 0.837242, Accuracy is 0.840000 The accuracy of validation set is 0.515200
# Iteration 10000: Cost is 1.003031, Accuracy is 0.750000 The accuracy of validation set is 0.496200
# Iteration 11000: Cost is 0.715103, Accuracy is 0.865000 The accuracy of validation set is 0.510600
# Iteration 12000: Cost is 0.500968, Accuracy is 0.930000 The accuracy of validation set is 0.510400
# Iteration 13000: Cost is 0.493188, Accuracy is 0.885000 The accuracy of validation set is 0.514000
# Iteration 14000: Cost is 0.494462, Accuracy is 0.935000 The accuracy of validation set is 0.517400

# %%
y_predicted = NN.predict(X_test)
save_predictions('ans1-jy2865', y_predicted)

# %%
# test if your numpy file has been saved correctly
loaded_y = np.load('ans1-jy2865.npy')
print(loaded_y.shape)
loaded_y[:10]
# Out:
# (10000,)
# array([4, 8, 0, 7, 5, 8, 8, 4, 8, 1])

# %% [markdown]
# ## Part 2: Improving the performance

# %% [markdown]
# ### Rmsprop optimization

# %%
layer_dimensions = [X_train.shape[0], 512, 512, 256, 256, 128, 128, 64, 32, 10]
NN2 = NeuralNetwork(layer_dimensions, drop_prob=0.0, reg_lambda=0.0,optimization_methods="rmsprop",beta=0.99)
NN2.train(X_train, y_train, iters=12000, alpha=0.001, batch_size=200, print_every=200)
# Out:
# Iteration     0: Cost is 2.299764, Accuracy is 0.145000 The accuracy of validation set is 0.097600
# Iteration   200: Cost is 2.055369, Accuracy is 0.155000 The accuracy of validation set is 0.196400
# Iteration   400: Cost is 2.037653, Accuracy is 0.255000 The accuracy of validation set is 0.239800
# Iteration   600: Cost is 1.971077, Accuracy is 0.285000 The accuracy of validation set is 0.319400
# Iteration  7200: Cost is 0.909218, Accuracy is 0.785000 The accuracy of validation set is 0.477200
# Iteration  7400: Cost is 0.872048, Accuracy is 0.785000 The accuracy of validation set is 0.481400
# Iteration  7600: Cost is 0.900726, Accuracy is 0.800000 The accuracy of validation set is 0.472000
# Iteration  7800: Cost is 0.840274, Accuracy is 0.795000 The accuracy of validation set is 0.472800
# Iteration  8000: Cost is 0.892161, Accuracy is 0.800000 The accuracy of validation set is 0.463400
# Iteration  8200: Cost is 0.990908, Accuracy is 0.805000 The accuracy of validation set is 0.458600
# Iteration  8400: Cost is 0.769143, Accuracy is 0.830000 The accuracy of validation set is 0.459600
# Iteration  8600: Cost is 0.837395, Accuracy is 0.795000 The accuracy of validation set is 0.456600
# Iteration  8800: Cost is 0.950370, Accuracy is 0.765000 The accuracy of validation set is 0.458200
# Iteration  9000: Cost is 0.679275, Accuracy is 0.850000 The accuracy of validation set is 0.462800
# Iteration  9200: Cost is 0.771055, Accuracy is 0.865000 The accuracy of validation set is 0.472400
# Iteration  9400: Cost is 0.594431, Accuracy is 0.875000 The accuracy of validation set is 0.462200
# Iteration  9600: Cost is 0.721107, Accuracy is 0.890000 The accuracy of validation set is 0.472200
# Iteration  9800: Cost is 0.745619, Accuracy is 0.860000 The accuracy of validation set is 0.466200
# Iteration 10000: Cost is 0.868595, Accuracy is 0.790000 The accuracy of validation set is 0.440800
# Iteration 10200: Cost is 0.630480, Accuracy is 0.865000 The accuracy of validation set is 0.464400
# Iteration 10400: Cost is 0.664696, Accuracy is 0.905000 The accuracy of validation set is 0.457200
# Iteration 10600: Cost is 0.682368, Accuracy is 0.850000 The accuracy of validation set is 0.451400
# Iteration 10800: Cost is 0.460483, Accuracy is 0.935000 The accuracy of validation set is 0.464200
# Iteration 11000: Cost is 0.593928, Accuracy is 0.865000 The accuracy of validation set is 0.455400
# Iteration 11200: Cost is 0.704783, Accuracy is 0.885000 The accuracy of validation set is 0.458600
# Iteration 11400: Cost is 0.600324, Accuracy is 0.920000 The accuracy of validation set is 0.456400
# Iteration 11600: Cost is 0.437626, Accuracy is 0.920000 The accuracy of validation set is 0.458000
# Iteration 11800: Cost is 0.374447, Accuracy is 0.920000 The accuracy of validation set is 0.468600

# %%
y_predicted2 = NN2.predict(X_test)
save_predictions( 'ans2_1_rmsprop-jy2865',y_predicted2)

# %% [markdown]
# ### Momentum

# %%
layer_dimensions = [X_train.shape[0], 512, 512, 256, 256, 128, 128, 64, 32, 10]
NN3 = NeuralNetwork(layer_dimensions, drop_prob=0.0, reg_lambda=0.001,optimization_methods="Momentum",beta=0.1)
NN3.train(X_train, y_train, iters=12000, alpha=0.05, batch_size=200, print_every=200)
# Out:
# Iteration     0: Cost is 3.247533, Accuracy is 0.140000 The accuracy of validation set is 0.121800
# Iteration   200: Cost is 2.941849, Accuracy is 0.240000 The accuracy of validation set is 0.230000
# Iteration   400: Cost is 2.947781, Accuracy is 0.280000 The accuracy of validation set is 0.294800
# Iteration   600: Cost is 2.751282, Accuracy is 0.320000 The accuracy of validation set is 0.338000
# Iteration  7200: Cost is 1.707776, Accuracy is 0.625000 The accuracy of validation set is 0.494400
# Iteration  7400: Cost is 1.788532, Accuracy is 0.585000 The accuracy of validation set is 0.474000
# Iteration  7600: Cost is 1.611586, Accuracy is 0.705000 The accuracy of validation set is 0.510400
# Iteration  7800: Cost is 1.651598, Accuracy is 0.635000 The accuracy of validation set is 0.463400
# Iteration  8000: Cost is 1.631158, Accuracy is 0.735000 The accuracy of validation set is 0.521200
# Iteration  8200: Cost is 1.700344, Accuracy is 0.645000 The accuracy of validation set is 0.490400
# Iteration  8400: Cost is 1.760701, Accuracy is 0.665000 The accuracy of validation set is 0.473400
# Iteration  8600: Cost is 1.671193, Accuracy is 0.620000 The accuracy of validation set is 0.509000
# Iteration  8800: Cost is 1.866760, Accuracy is 0.555000 The accuracy of validation set is 0.474000
# Iteration  9000: Cost is 1.644813, Accuracy is 0.660000 The accuracy of validation set is 0.473600
# Iteration  9200: Cost is 1.732953, Accuracy is 0.645000 The accuracy of validation set is 0.483000
# Iteration  9400: Cost is 1.540998, Accuracy is 0.725000 The accuracy of validation set is 0.496800
# Iteration  9600: Cost is 1.466517, Accuracy is 0.770000 The accuracy of validation set is 0.523000
# Iteration  9800: Cost is 1.588027, Accuracy is 0.700000 The accuracy of validation set is 0.498800
# Iteration 10000: Cost is 1.520287, Accuracy is 0.675000 The accuracy of validation set is 0.493400
# Iteration 10200: Cost is 1.482206, Accuracy is 0.730000 The accuracy of validation set is 0.511800
# Iteration 10400: Cost is 1.701534, Accuracy is 0.695000 The accuracy of validation set is 0.493000
# Iteration 10600: Cost is 1.571202, Accuracy is 0.670000 The accuracy of validation set is 0.499000
# Iteration 10800: Cost is 1.345579, Accuracy is 0.840000 The accuracy of validation set is 0.529800
# Iteration 11000: Cost is 1.518500, Accuracy is 0.735000 The accuracy of validation set is 0.523000
# Iteration 11200: Cost is 1.345023, Accuracy is 0.790000 The accuracy of validation set is 0.522200
# Iteration 11400: Cost is 1.451126, Accuracy is 0.720000 The accuracy of validation set is 0.492600
# Iteration 11600: Cost is 1.323535, Accuracy is 0.755000 The accuracy of validation set is 0.504200
# Iteration 11800: Cost is 1.249509, Accuracy is 0.825000 The accuracy of validation set is 0.522600

# %%
y_predicted3 = NN3.predict(X_test)
save_predictions( 'ans2_2_momentum-jy2865',y_predicted3)

# %% [markdown]
# ### Adam

# %%
layer_dimensions = [X_train.shape[0], 512, 512, 256, 256, 128, 128, 64, 32, 10]
NN4 = NeuralNetwork(layer_dimensions, drop_prob=0.0, reg_lambda=0.001,optimization_methods="adam",beta=0.9,beta_2=0.95)
NN4.train(X_train, y_train, iters=12000, alpha=0.001, batch_size=200, print_every=200)
# Out:
# Iteration     0: Cost is 3.247533, Accuracy is 0.145000 The accuracy of validation set is 0.098000
# Iteration   200: Cost is 2.817935, Accuracy is 0.360000 The accuracy of validation set is 0.288600
# Iteration   400: Cost is 2.821776, Accuracy is 0.320000 The accuracy of validation set is 0.355400
# Iteration   600: Cost is 2.762012, Accuracy is 0.420000 The accuracy of validation set is 0.389800
# Iteration  7200: Cost is 3.297531, Accuracy is 0.820000 The accuracy of validation set is 0.516000
# Iteration  7400: Cost is 3.395821, Accuracy is 0.875000 The accuracy of validation set is 0.513200
# Iteration  7600: Cost is 3.387582, Accuracy is 0.815000 The accuracy of validation set is 0.503200
# Iteration  7800: Cost is 3.471689, Accuracy is 0.830000 The accuracy of validation set is 0.502600
# Iteration  8000: Cost is 3.560488, Accuracy is 0.835000 The accuracy of validation set is 0.498400
# Iteration  8200: Cost is 3.601556, Accuracy is 0.860000 The accuracy of validation set is 0.504800
# Iteration  8400: Cost is 3.637382, Accuracy is 0.850000 The accuracy of validation set is 0.503200
# Iteration  8600: Cost is 3.613695, Accuracy is 0.855000 The accuracy of validation set is 0.503400
# Iteration  8800: Cost is 3.772066, Accuracy is 0.870000 The accuracy of validation set is 0.503600
# Iteration  9000: Cost is 3.632589, Accuracy is 0.900000 The accuracy of validation set is 0.498800
# Iteration  9200: Cost is 3.767548, Accuracy is 0.870000 The accuracy of validation set is 0.506400
# Iteration  9400: Cost is 3.753136, Accuracy is 0.895000 The accuracy of validation set is 0.514000
# Iteration  9600: Cost is 3.836018, Accuracy is 0.885000 The accuracy of validation set is 0.491400
# Iteration  9800: Cost is 3.786449, Accuracy is 0.940000 The accuracy of validation set is 0.497800
# Iteration 10000: Cost is 3.847707, Accuracy is 0.890000 The accuracy of validation set is 0.513400
# Iteration 10200: Cost is 4.060158, Accuracy is 0.900000 The accuracy of validation set is 0.504000
# Iteration 10400: Cost is 4.051806, Accuracy is 0.915000 The accuracy of validation set is 0.507200
# Iteration 10600: Cost is 4.052215, Accuracy is 0.900000 The accuracy of validation set is 0.505800
# Iteration 10800: Cost is 4.061939, Accuracy is 0.935000 The accuracy of validation set is 0.505000
# Iteration 11000: Cost is 4.164549, Accuracy is 0.930000 The accuracy of validation set is 0.492800
# Iteration 11200: Cost is 4.257832, Accuracy is 0.920000 The accuracy of validation set is 0.497800
# Iteration 11400: Cost is 4.157571, Accuracy is 0.940000 The accuracy of validation set is 0.492800
# Iteration 11600: Cost is 4.226130, Accuracy is 0.925000 The accuracy of validation set is 0.492000
# Iteration 11800: Cost is 4.288110, Accuracy is 0.935000 The accuracy of validation set is 0.501200

# %%
y_predicted4 = NN4.predict(X_test)
save_predictions( 'ans2_3_adam-jy2865',y_predicted4)

# %% [markdown]
# ### Data Augmentation

# %%
layer_dimensions = [X_train.shape[0], 512, 512, 256, 256, 128, 128, 64, 32, 10]
NN4 = NeuralNetwork(layer_dimensions, drop_prob=0.0, reg_lambda=0.001,optimization_methods="adam",beta=0.9,beta_2=0.95)
NN4.train(X_train, y_train, iters=12000, alpha=0.001, batch_size=200, print_every=200,data_aug = "rotate")
# Out:
# (50000,)
# Iteration     0: Cost is 3.249786, Accuracy is 0.120000 The accuracy of validation set is 0.122700
# Iteration   200: Cost is 2.855226, Accuracy is 0.320000 The accuracy of validation set is 0.296100
# Iteration   400: Cost is 2.914183, Accuracy is 0.320000 The accuracy of validation set is 0.323100
